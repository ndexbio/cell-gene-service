# %% [markdown]
# Notebook for testing this service

# %%
# Class for fetching data from matrix
# Author: Massoud Maher

import pandas as pd
import os

cell_matrix = pd.read_csv('CCLE_inferred_prot_abundance.tab', sep='\t', index_col=True)

cell_matrix
# Out:
#         Description  LN18_CENTRAL_NERVOUS_SYSTEM  X769P_KIDNEY  X786O_KIDNEY  \
# 0      LOC100009676                  2944.648058   1813.368480   2589.958311
# 1              AKT3                  3606.518831   9576.297806   8258.282081
# 2              MED6                 28839.907473  20005.456291  16679.635267
# 3             NR2E3                   290.507712    466.898399    280.319901
# 4           NAALAD2                   215.364856    239.906282    398.967384
# 5        CDKN2B-AS1                   298.788505    410.416321    624.316625
# 6      LOC100049716                   482.755104    371.545309    571.968045
# 7          NAALADL1                   589.928257    704.076217    654.951432
# 8             ACOT8                 23436.487366  10884.056290  14486.300100
# 9              ABI1                  9172.816841  27068.178564  20628.937741
# 10           GNPDA1                 36688.418613  43571.747022  22809.957967
# ...
